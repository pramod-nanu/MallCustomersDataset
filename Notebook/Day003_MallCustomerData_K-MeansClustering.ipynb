# %% [markdown]
# ### Apply K-Means Clustering

# %% [markdown]
# ### Topic 1: Select Features for K-Means

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("mall_customers_loadsheet.csv")
# print(df.head())
X = df[['Age','Annual Income (k$)','Spending Score (1-100)']]
print(X.head())
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   49                  68                      86
# 1   56                  22                      57
# 2   66                  41                      29
# 3   69                  41                      78
# 4   49                 112                      92

# %% [markdown]
# ### Topic 2: Standardize Features using StandardScaler

# %%
### Code to Standardize Features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled[:5]
# Out:
# array([[ 0.30002513, -0.24775902,  1.17008672],
#        [ 0.75708192, -1.50917739,  0.19501445],
#        [ 1.41002018, -0.98815676, -0.74643463],
#        [ 1.60590166, -0.98815676,  0.90110127],
#        [ 0.30002513,  0.95881507,  1.37182581]])

# %% [markdown]
# ### Topic 3: Apply K-Means for Different Values of k

# %%
from sklearn.cluster import KMeans
inertia_values = []
for k in range(1,11):
    kmeans = KMeans(n_clusters = k,random_state = 42)
    kmeans.fit(X_scaled)
    inertia_values.append(kmeans.inertia_)
print(inertia_values)
# Out:
# [600.0, 440.72987729033946, 340.27257218614204, 271.6305725916759, 219.94928160571015, 184.7803965356714, 166.8283094852053, 139.79973421401564, 127.63050934337195, 118.74187352428099]

# %% [markdown]
# ### Topic 4: Elbow Curve

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),inertia_values,marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Curve for K-Means")
plt.savefig("Images/elbow_curve.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Topic 5: Choose Optimal k & Final Decision

# %% [markdown]
# ### Chosen optimal k = 4
