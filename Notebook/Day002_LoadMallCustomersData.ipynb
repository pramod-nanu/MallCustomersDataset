# %% [markdown]
# # EDA – Exploratory Data Analysis

# %% [markdown]
# ### Topic 1: Distribution Plots for Age, Income & Spending Score

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("mall_customers_loadsheet.csv")
sns.histplot(df['Age'],kde = True)
plt.title("Age Distribution")
plt.savefig("Images/Age Distribution.png", dpi=300, bbox_inches="tight")
plt.show()

sns.histplot(df['Annual Income (k$)'],kde=True)
plt.title("Income Distribution")
plt.savefig("Images/Income Distribution.png",dpi = 300,bbox_inches='tight')
plt.show()

sns.histplot(df["Spending Score (1-100)"], kde=True)
plt.title("Spending Score Distribution")
plt.savefig("Images/Spendinf Score Distribution.png",dpi = 300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Topic 2: Average Spending Score by Gender

# %%
df.columns
sns.barplot(data=df,x='Gender',y='Annual Income (k$)')
plt.title("Avarage Spending Score by Gender")
plt.savefig("Images/BarplotGenderWiseSepnding",dpi  = 300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ✅ Topic 3: Pairplot

# %%
pair = sns.pairplot(
    df[["Age", "Annual Income (k$)", "Spending Score (1-100)"]]
)

pair.savefig("Images/pairplot_age_income_spending.png", dpi=300)

# %% [markdown]
# ### Topic 4: Correlation Heatmap

# %%
corr = df[["Age", "Annual Income (k$)", "Spending Score (1-100)"]].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
